# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\sdhar\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\sdhar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\sdhar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\sdhar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\sdhar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\Users\sdhar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import string
df=pd.read_csv("D:\Twitter Sentiments.csv")
df=df.drop(columns=['id','label'])
df.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\sdhar\AppData\Local\Temp\ipykernel_8032\2793470768.py:3: SyntaxWarning: invalid escape sequence '\T'
#   df=pd.read_csv("D:\Twitter Sentiments.csv")
#                                                tweet
# 0  @user when a father is dysfunctional and is so...
# 1  @user @user thanks for #lyft credit i can't us...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation

# %%
text = "Data DATA data DaTa"

lower_text = text.lower()

print(lower_text)
# Out:
# data data data data

# %%
import string

text = "Hello, World! How are you?"

no_punctuation = text.translate(str.maketrans('', '', string.punctuation))

print(no_punctuation)
# Out:
# Hello World How are you

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

text = "The cat is sitting on the mat"

words = text.split()

stop_words = set(stopwords.words('english'))

filtered_words = [word for word in words if word.lower() not in stop_words]

print(filtered_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# ['cat', 'sitting', 'mat']
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')

text = "I love NLP."

words = word_tokenize(text)

print(words)
# Out:
# ['I', 'love', 'NLP', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize

nltk.download('punkt')

text = "Hello. How are you? I am fine."

sentences = sent_tokenize(text)

print(sentences)
# Out:
# ['Hello.', 'How are you?', 'I am fine.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

words = ["running", "studies", "children", "better"]

for word in words:
    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# running -> running
# studies -> study
# children -> child
# better -> better

# %%
from sklearn.feature_extraction.text import CountVectorizer

documents = [
    "I love NLP",
    "I love AI"
]

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())

print(X.toarray())
# Out:
# ['ai' 'love' 'nlp']
# [[0 1 1]
#  [1 1 0]]

# %%
import string
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')

text = "Natural Language Processing is amazing!"

# Step 1: Lowercase
text = text.lower()

# Step 2: Remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))

# Step 3: Tokenization
tokens = word_tokenize(text)

# Step 4: Stopword Removal
stop_words = set(stopwords.words('english'))
tokens = [word for word in tokens if word not in stop_words]

# Step 5: Stemming
stemmer = PorterStemmer()
tokens = [stemmer.stem(word) for word in tokens]

print(tokens)
# Out:
# ['natur', 'languag', 'process', 'amaz']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sdhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
